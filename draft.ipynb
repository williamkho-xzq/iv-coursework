# %%
import altair as alt
import pandas as pd
import numpy as np
import timeit
from IPython.display import Image, display

alt.data_transformers.enable("vegafusion")
# Out:
# DataTransformerRegistry.enable('vegafusion')

# %%
tvseries_fname = "TMDB_tv_dataset_v3.csv"

# %%
# Load data
tvseries_df = pd.read_csv("data/"+tvseries_fname)

# %%
# TV Series - Attributes
print("Rows: ", len(tvseries_df))
print("Columns: ", len(tvseries_df.columns))
print(list(tvseries_df.columns))
print("-----------")
# print(tvseries_df["episode_run_time"].unique())
# Out:
# Rows:  166383
# Columns:  29
# ['id', 'name', 'number_of_seasons', 'number_of_episodes', 'original_language', 'vote_count', 'vote_average', 'overview', 'adult', 'backdrop_path', 'first_air_date', 'last_air_date', 'homepage', 'in_production', 'original_name', 'popularity', 'poster_path', 'type', 'status', 'tagline', 'genres', 'created_by', 'languages', 'networks', 'origin_country', 'spoken_languages', 'production_companies', 'production_countries', 'episode_run_time']
# -----------

# %%
# TV Series - Attributes
# ---------------------------------------------------
# id - Integer, quantitative???
# name - String, categorical 
# number_of_seasons - integer, quantitative
# number_of_episodes - integer, quantitative
# original_language - String, categorical - iso language code
# vote_count - Integer, quantitative, sequential
# vote_average - Double, quantitative, sequential
# overview - String, categorical - movie summary, kinda useless - useless
# adult - boolean, categorical
# backdrop_path - String, categorical - should be removed cause it store image path - useless
# first_air_date - Date, sequential
# last_air_date - Date, sequential
# homepage - String, categorical - should be removed cause it refers to the movie's website - useless
# in_production - Boolean, - not sure what it could bring to table
# original_name - String, categorical - not sure how useful
# popularity - Double, Sequential - not sure what the value represent
# poster_path - String, categorical - remove this, poster image - useless
# type - String, categorical
# status - String, categorical
# tagline - String, categorical - not sure this field could be meaningful - useless
# genres - List<String>, categorical - contains multiple value, candidate for connection/graph
# created_by - String, quantitative
# languages - List<String>, categorical - contains multiple value, not sure how good this is
# networks - List<String>, categorical
# origin_country - String, categorical
# spoken_languages - List<String>, categorical - contains multiple value, not sure how good this is - useless
# production_companies - List<String>, categorical - contains multiple value, candidate for connection/graph
# production_countries - List<String>, categorical - contains multiple value, candidate for connection/graph
# episode_run_time - Integer, sequential - duration in minutes per episode, some are zero

# %%
tvseries_df.isna().sum()
# Out:
# id                           0
# name                         5
# number_of_seasons            0
# number_of_episodes           0
# original_language            0
# vote_count                   0
# vote_average                 0
# overview                 73834
# adult                        0
# backdrop_path            89285
# first_air_date           31478
# last_air_date            29646
# homepage                115768
# in_production                0
# original_name                5
# popularity                   0
# poster_path              59099
# type                         0
# status                       0
# tagline                 161074
# genres                   67628
# created_by              130225
# languages                57415
# networks                 69546
# origin_country           31025
# spoken_languages         58174
# production_companies    107630
# production_countries     89679
# episode_run_time             0
# dtype: int64

# %%
tvseries_df_columns = tvseries_df.columns
for column in tvseries_df_columns:
    print(column)
    print(tvseries_df[column].unique())
    print()
    print()
# Out:
# id
# [  1399  71446  66732 ... 239216 239217 239218]
#
#
# name
# ['Game of Thrones' 'Money Heist' 'Stranger Things' ... 'Parenting'
#  'BPM Ecstasy' 'Génération 2008 : qui seront-ils demain ?']
#
#
# number_of_seasons
# [  8   3   4  11   6   7   2   5   1   9  12  19  35  20  10  15  21  22
#   26  16  24  14  13  25  30  33  27  17  29  49  45  31  23  18  53  39
#    0  72  51  32  37  40  36  54  50  64  34  38  41  71  28  56  66  47
#   42  60 240  68  59 188  43  67  52  74  46  80  73  61  57  44  63  75
#   84  48  58  62  55  70 134 101  95 111]
#
#
# number_of_episodes
# [   73    41    34   177    93   137     9    62   116   184   279    12
#    419    24   762    16    32    36    49    71   171     6   500   100
#      8   228   327    89    26    50    55   170    87     5   130   220
#    441    96   131   113    88   138   134    27   208    63   129    33
#     45   291  1080    39   126   151   411   321     7   216   118    37
#     61   186   334    10   538   136    20   335    92    52   246   152
#    122   262   218    35     2   153    40    47    30   699    68   578
#    340    56   161    83   250   293    86    51    91    23   110   127
#     19    76    48   178   148   457    43    78   239    44   156   259
#     60    18    94   366   121   193    14    11    17   257    64   183
#    133    57   320   180    80   173    46   179   392    25    70   182
#     22   107  1234   240    59   144    65   103    28   154   232    38
#    124    98    90   197    85   172   149    53    13   214    75   102
#     95    29   204   105   176   200   125   140   190   146   128    84
#     21   114    79   226   139   323   169   264    69   145   163   101
#    192   265   258   115   328     3   268   282   224   108   269    58
#    166    31    67     4    42   104   275   331   158   221   223   106
#     82    97   120   973   210    15   444    74   284   219   273   254
#   1100   322    99   227   281   215    54  1835   251   160   300   386
#     77   207   185    72   253   117   395   181   255   694   123   194
#    272   488   202   111  3830   317   162   422   212   157   242   112
#     81   187   155   431   175   951   201   656   132   318   119   165
#    230   363   241   189   206   579    66   231   195   229   147  1599
#    109   650   350  1447   263   196  1233   447   332   428   252   209
#    274   494   237  3048   188  1419   884  1510  3306   142   150   164
#   6697   296   902   298   580     0   243   635   357   367   135   234
#    680   845  1195   203     1   167  2012 20839   566   266   361  1273
#    222   302   405   493   458   168  2373   225   141  2632   198   233
#   4252   312   416   736   249   406  1969  2724   261   310  7296  8560
#    506   270   159   205  1199   716   743   271   236   584   359  1265
#   1249   964   191   850   301   278   376   554  3337   483  1558   381
#    530   373  6604  4548  1255   423  2391   267   970   892  2057  2643
#    389  1606  2550   511   238   994  1303   981   174  2206   308  1225
#    199   365  3563   400   247   839   591   589   244  3483  1045  8073
#   2924   307  1426   276   726   614   325  1252  1341   764   409   446
#    287   815  8915   967   403  1377  1529  2591   283  2544   143   784
#   1484  1220   417   793   294   461   468   435  1102   303  1651   682
#    734  1769   575   313   393  3626   256  1610   217  6114   797   324
#    634  2137   545   304  1060   552   485   474  3129   380   768  1004
#    396   404  1144   426   638  3919   399   592   344   364   755   372
#    292   636   410   286  1291   804   692   622  1169   482  2107   311
#    305   704   643  1135  1161   299   701  4667   601 15704  6224   585
#    358   957   697  1302   896   245   391   260  1438  7880   769  1442
#    504   876  1178  2205  1201  1044   537   378  2850   616   314   338
#    368  1114  2378   531  4064  1186  2013   438   561   526   520   880
#    544   353   288   507   356   289   375  1068  3822   316   571   750
#    336  1538  5753   515   491   495  1034   459   484  1369   603   600
#    753   901   390  7288   379   464  5348   408  5817   525   466   430
#    974   442   728   347  1240   248   781   627   401  1603   306   871
#   1553   932   454  7535   501   354   285   780   565   558   598   337
#    481  1689   295   670   881   510   647   885   470  2917  1588  1462
#    377  1673   355   297   383   382   433  3182   437  1002   352   586
#    492  1069   573   479  1964   847  1684   277   710   991   427  1085
#   3561   351  2134   452  1737  1282  1464  3398   613  1722  1382  1137
#    315   817   556   362   618   436   529   211   480  4343   604  4438
#    722  1123  1124   820   455   385   384   742   290  6395   235   766
#   3673   420   424 10456   370   693   567   570   870   645   659  1506
#    863   774   518   733   465   517   640  1052  4546  1416   926   695
#   2000   714  1116  1716  1566   333   456   213   832  1330  1229  2837
#    346  1025   676   818   343   341   425  1118   595   807   547  1844
#    533   564  3017   879   658  1547   782   329   758   854  2439  2075
#   1070   928   788   663   432   360   773  2640  1364   512   623   387
#   3556   972   681   348   319   857   741  3211  1073  3300   471   834
#   1857  3656  2201  1147   916   934  6202   675  1075  1038   685  1056
#    775   729   453   961   539   619   574   551   549   280  2132   860
#    673   610  1061  1260  1145   800   679   875  3348   496   605  1680
#    443   562   412   998   369   689   828   660   524   374   620   309
#    667   469   397   398   653   651   429  1540   583  3271   460  4689
#    609   576  1906   349   568   394  2074  1640   789  1078   712   772
#    342   801   599   632   785  1111   708  4801  2155   740   810   612
#    577   919   528   672   388   900   761   588   523   791  3894  4724
#    776  4342   814   548   499   414   587  3613  1032  1676   463   925
#    505   631   330  1920   472   644   590   607   421  1865   642   371
#    669  1050   594  2497  1065   727  1112  1026  1432   621   737  2255
#    799   345  3318   995  1190   624   872   752   966   473   326  2086
#    490   541  1095   560  3824   944   462   671   497   899   777   508
#   1537   451   415   407  1310  1016   759  2190   572   825   936  4279
#   1094  1480   439   563  1066   487  3893   628   440   478   639   688
#   1221  2041   597   637   418   477   706  2357   738  1121  2098   978
#   1937   874   649  1213   514   625   448   513  1810   475  1359   720
#   1259   794   535  1816   790  3760   540]
#
#
# original_language
# ['en' 'es' 'ko' 'ja' 'de' 'fr' 'tr' 'pt' 'da' 'ca' 'sv' 'no' 'th' 'it'
#  'zh' 'ar' 'ru' 'is' 'tl' 'he' 'pl' 'nl' 'hi' 'fi' 'lb' 'cy' 'gl' 'uk'
#  'hu' 'cs' 'la' 'ro' 'bg' 'cn' 'el' 'vi' 'ta' 'sr' 'hr' 'xx' 'fa' 'zu'
#  'bn' 'id' 'sk' 'ur' 'ms' 'te' 'sh' 'af' 'kn' 'ga' 'et' 'si' 'bs' 'ml'
#  'az' 'ka' 'am' 'sq' 'nb' 'ab' 'mo' 'eu' 'lv' 'hz' 'mr' 'sl' 'ku' 'lt'
#  'mk' 'pa' 'or' 'st' 'as' 'gu' 'jv' 'my' 'so' 'ti' 'mt' 'ne' 'mi' 'sw'
#  'mn' 'be' 'se' 'kk' 'km' 'gd' 'kv' 'dv' 'hy' 'fy' 'av' 'ps' 'aa' 'ln'
#  'lo' 'ht' 'uz' 'rm' 'za' 'ho' 'eo' 'ug']
#
#
# vote_count
# [21857 17836 16161 ...     2     1     0]
#
#
# vote_average
# [8.442 8.257 8.624 ... 0.5   2.25  0.   ]
#
#
# overview
# ["Seven noble families fight for control of the mythical land of Westeros. Friction between the houses leads to full-scale war. All while a very ancient evil awakens in the farthest north. Amidst the war, a neglected military order of misfits, the Night's Watch, is all that stands between the realms of men and icy horrors beyond."
#  'To carry out the biggest heist in history, a mysterious man called The Professor recruits a band of eight robbers who have a single characteristic: none of them has anything to lose. Five months of seclusion - memorizing every step, every detail, every probability - culminate in eleven days locked up in the National Coinage and Stamp Factory of Spain, surrounded by police forces and with dozens of hostages in their power, to find out whether their suicide wager will lead to everything or nothing.'
#  'When a young boy vanishes, a small town uncovers a mystery involving secret experiments, terrifying supernatural forces, and one strange little girl.'
#  ...
#  "Nine previous Big Brother houseguests have recieved an invitation from Santa to compete in a brand-new game. They'll play in a variety of holiday-themed competitions until just four Big Brother legends remain. One player will walk away with Santa's blessing, and a $100,000 grand prize to boot."
#  "The world was in disarray and the people were in grave difficulties in the desolation of Doomsday, the third year of King Shizong's rule. The Demon Gate Demon Party lurks in the shadows, wreaking havoc. The gangs attack each other, causing mayhem. Various sects developed one after the other in the pandemonium, battling for resources and territory and establishing their own control. There are ambitious people who want to rule the globe and create a dynasty, and there are good people who wish to help the common people. Wei He carries the realm-breaking bead, which allows him to travel through tumultuous periods and construct his own mythology step by step.(Bstation)"
#  'Driven by her hatred of Shin Tae Hwan, the mine manager, a nurse switches his newborn son with the newborn son of Lee Ki Chul, a miner, and a chain of events is set in motion that will tear apart the lives of everyone involved.']
#
#
# adult
# [False  True]
#
#
# backdrop_path
# ['/2OMB0ynKlyIenMJWI2Dy9IWT4c.jpg' '/gFZriCkpJYsApPZEF3jhxL4yLzG.jpg'
#  '/2MaumbgBlW1NoPo3ZJO38A6v7OS.jpg' ... '/15kPSa7gHDMAQkn03ysvjSntgkw.jpg'
#  '/dJewjBFirRCK6AECh8m1SbdHhsm.jpg' '/uYTppC60aDL6pZsZOc1PLlErFwO.jpg']
#
#
# first_air_date
# ['4/17/2011' '5/2/2017' '7/15/2016' ... '6/16/2024' '2/17/2024'
#  '8/11/1998']
#
#
# last_air_date
# ['5/19/2019' '12/3/2021' '7/1/2022' ... '5/4/1979' '10/9/1981' '8/14/1995']
#
#
# homepage
# ['http://www.hbo.com/game-of-thrones'
#  'https://www.netflix.com/title/80192098'
#  'https://www.netflix.com/title/80057281' ...
#  'https://www.oprah.com/app/rebuilding-black-wall-street.html'
#  'https://www.nelonen.fi/ohjelmat/rekkakuskit-suomi'
#  'https://npo.nl/start/serie/selma-op-mijn-manier']
#
#
# in_production
# [False  True]
#
#
# original_name
# ['Game of Thrones' 'La Casa de Papel' 'Stranger Things' ... 'BPM Ecstasy'
#  'Génération 2008 : qui seront-ils demain ?' 'Edeonui dongjjok']
#
#
# popularity
# [1083.917   96.354  185.711 ...   14.233   57.162   13.137]
#
#
# poster_path
# ['/1XS1oqL89opfnbLl8WnZY1O1uJx.jpg' '/reEMJA1uzscCbkpeRJeTT2bjqUp.jpg'
#  '/49WJfeN0moxb9IPfGn8AIqMGskD.jpg' ... '/7NRPnQAPzCByFDS5eAeQk1v0Gip.jpg'
#  '/c3SGq7iM7gwLqrhmIFkpAtV8jii.jpg' '/tdQ4jcGY62HnxcsYWHA4KfSJ6pw.jpg']
#
#
# type
# ['Scripted' 'Miniseries' 'Documentary' 'Reality' 'Talk Show' 'News'
#  'Video']
#
#
# status
# ['Ended' 'Returning Series' 'Canceled' 'Pilot' 'In Production' 'Planned']
#
#
# tagline
# ['Winter Is Coming' 'The perfect robbery.' 'Every ending has a beginning.'
#  ... 'Can lies heal?' "I'm Addicted to You."
#  "it's eddsworld, we'er just living in it"]
#
#
# genres
# ['Sci-Fi & Fantasy, Drama, Action & Adventure' 'Crime, Drama'
#  'Drama, Sci-Fi & Fantasy, Mystery' ... 'News, Reality, Talk'
#  'Sci-Fi & Fantasy, Action & Adventure, War & Politics'
#  'Animation, Comedy, Documentary']
#
#
# created_by
# ['David Benioff, D.B. Weiss' 'Álex Pina' 'Matt Duffer, Ross Duffer' ...
#  'Seth Da Silva' 'Olivier Richard' 'François Chevré']
#
#
# languages
# ['en' 'es' 'en, ko, ur' ... 'sa' 'da, en, uk' 'aa, af']
#
#
# networks
# ['HBO' 'Netflix, Antena 3' 'Netflix' ... 'Atresplayer'
#  'Ukraine, First Channel' 'Arte , Taiwan+']
#
#
# origin_country
# ['US' 'ES' 'KR' 'GB' 'JP' 'CA' 'DE' 'MX' 'FR' 'CO' 'TR' 'GB, US' 'CA, US'
#  'AR' 'CA, US, GB' 'US, GB' 'BR' 'US, CA' 'DK' 'IE' 'SE' 'NO' 'TH' 'IT'
#  nan 'DE, IT, ZA, TR, GB, US' 'CO, US' 'KR, NC' 'CN' 'CL' 'AU' 'MX, US'
#  'JO' 'VE, CO, US' 'US, AU' 'BE' 'ES, GB' 'IT, GB' 'US, CO' 'RU' 'PR'
#  'US, MX' 'FR, US' 'JM, JP' 'JP, US' 'NZ, US, GB' 'AR, BR' 'ZA' 'IS'
#  'AU, US' 'US, BE, FR, CA' 'PH' 'BR, US' 'AT, DE' 'IL' 'MX, ES' 'SI, ES'
#  'PL' 'PE' 'US, NL' 'CA, FR' 'IN' 'AT' 'NZ' 'RU, UA' 'ES, MX' 'CA, GB'
#  'EG' 'VE' 'US, JP' 'DE, US, ZA' 'FR, IT, ES, GB, US' 'US, GB, CA' 'NG'
#  'CA, US, JP' 'JP, ES' 'CA, FR, US' 'US, NG' 'CH, GB' 'DE, US' 'IT, US'
#  'ES, CO, US' 'AR, CO, GB' 'FI' 'US, IL' 'SU' 'CA, FR, US, DE'
#  'AT, CH, DE' 'DE, CZ' 'BE, DE, US, FR' 'DE, FR' 'AR, MX' 'GB, CA'
#  'DE, CA, GB' 'US, KR' 'VE, US' 'DE, US, GB' 'TW' 'LU' 'NL' 'EC' 'DE, LU'
#  'VE, MX, US' 'FR, JP' 'DE, DK, SE' 'ZA, GB, DE' 'US, SE' 'FR, IT'
#  'DE, US, IT, YU' 'NZ, AU' 'UA' 'HU' 'FR, GB' 'CO, MX, US' 'AU, DE, SG'
#  'AU, GB' 'FR, CA' 'CA, US, FR, GB' 'XC' 'US, TR' 'FI, JP' 'FR, SE'
#  'IQ, US' 'PT' 'IE, GB' 'BE, LU' 'AU, CA, US' 'BE, US' 'AU, GB, US'
#  'GB, IT' 'CA, FR, JP, US' 'SG' 'BE, FR' 'AU, NZ' 'JP, PH, GB, US'
#  'IT, DE, US, FR' 'RO' 'US, RU' 'CA, FR, GB' 'CA, CN' 'CZ, XC'
#  'GB, DE, IT, FR' 'BG' 'US, FR, JP' 'AT, BE, DK, DE, CH' 'ES, US'
#  'DE, IT, GB' 'US, VE' 'AE' 'DE, GB, US' 'US, FR' 'DE, CL' 'US, AU, PL'
#  'FR, DE, US' 'DE, FR, IT, PL, RU' 'DK, FI, NO, GB, SE, DE' 'HK' 'CH'
#  'DE, NO, NL' 'GR' 'FR, DE' 'JO, US' 'AU, CN, DK, US' 'AR, UY' 'UY'
#  'CL, CO' 'NZ, GB' 'JP, CA, US, FR' 'QA' 'VN' 'NL, BE' 'KE' 'TW, MY' 'RS'
#  'CZ' 'PL, US' 'GB, IE, ES, IT, CA, DE, FR' 'US, AU, CA' 'DE, IT' 'PL, GB'
#  'DE, AT' 'HR' 'DK, SE' 'IR' 'GB, FR, CA' 'XG, DE' 'ES, PT' 'BE, NL'
#  'AU, FR, DE' 'NL, GB' 'FR, TR' 'US, IN' 'BD, IN' 'FR, IL' 'LB, SY'
#  'US, SG' 'US, DE, HR, IE' 'JP, CN' 'BO' 'ID' 'AR, PE' 'KR, US'
#  'ID, KR, US, FR' 'IO' 'FR, CA, US' 'ES, IT' 'LB' 'GB, IE' 'TW, CN'
#  'AT, SK, CZ, HU' 'PK' 'JP, GB' 'RU, SU' 'MY' 'CA, CN, US' 'AT, CY, TH'
#  'KR, US, MX' 'DE, NZ' 'CA, ZA' 'GB, IT, US' 'GB, DE, US' 'CU' 'JP, IT'
#  'AR, ES' 'DE, IT, LU' 'JP, LV' 'JP, NL' 'KW' 'AT, US, GB' 'PL, XG, SU'
#  'CA, US, FR, IO' 'AU, DE' 'BD' 'CN, JP' 'CA, GB, US' 'SA' 'ES, FR'
#  'NO, SE' 'US, JP, CA' 'CA, NZ' 'KR, ES' 'DK, IE, SE' 'CA, JP, US'
#  'IT, DE, US' 'JP, TW' 'AR, BR, UY' 'CA, MX, FR' 'AU, CA' 'FR, DE, LU'
#  'FR, KR, US' 'FR, ES' 'IT, JP' 'DE, CH, YU' 'IE, CA, US' 'TO, TR'
#  'HR, UA' 'SK, UA' 'IE, CA' 'SY' 'DE, SE' 'KZ' 'KP, KR' 'DK, NO, SE'
#  'BR, CA' 'US, NZ' 'IQ' 'SK' 'GB, US, CA' 'YU' 'DE, AU' 'NZ, US' 'PT, ES'
#  'DK, FI, NO, SE' 'CA, DE' 'BE, FR, DE' 'GB, US, AU' 'BA, RS' 'FR, JP, ES'
#  'JP, KR' 'CA, US, FR, GB, TW' 'MA' 'CO, GB' 'DE, FR, IT' 'CA, IN, GB'
#  'CN, TW' 'US, DK' 'RU, TR' 'IT, ES' 'BE, FR, US' 'CA, DK, LU, US'
#  'FR, IT, US' 'AT, DE, CZ' 'DE, AT, CH' 'DK, DE, NO, SE, GB, US' 'DE, CA'
#  'GB, ES' 'XC, CZ' 'DE, CU' 'ZA, US' 'GB, AU' 'CL, FI' 'BR, FR' 'AR, FR'
#  'AT, CA, FR, DE, NL, GB' 'DE, GB' 'CZ, SK' 'EE' 'AT, US, IT' 'US, GB, AU'
#  'US, NL, CA' 'CN, HK' 'BA' 'AU, SG' 'CA, MD' 'CN, HK, TW, SG' 'FR, GR'
#  'KR, JP' 'XG' 'DE, AT, XC, ES, FR, IT, SE' 'LK' 'LB, EG' 'CO, VE'
#  'SU, US, GB' 'TN' 'IO, US' 'IE, US' 'AR, BR, MX' 'AZ' 'GE' 'DO' 'IO, GB'
#  'CN, MN' 'GB, DE, FR' 'GR, CY' 'US, ZA' 'BD, IT' 'IO, IN' 'SN' 'TZ'
#  'US, IE' 'AL' 'VE, CO' 'CN, US' 'IN, SG' 'AT, FR, DE' 'IN, IO' 'FI, SE'
#  'HK, TW' 'QA, SA, SY' 'US, GT' 'AE, BH, KW, SA' 'GB, FR' 'PE, VE' 'MV'
#  'FR, IN, DE, US' 'US, AU, GB, CA' 'MY, SG' 'US, ZA, GB' 'RU, UA, FR'
#  'CA, FR, GB, ES, US' 'EG, LB, MA, SA, TN' 'US, CH' 'PL, TR' 'IS, DE'
#  'PR, US' 'MX, PH' 'AU, FR' 'AU, BE, DE' 'XK' 'ES, TW, GB' 'CN, HK, KR'
#  'US, BE, CA' 'CN, SG' 'GB, NZ' 'CA, JP, KP' 'AT, FR' 'IN, PK' 'CN, MX'
#  'JP, NZ' 'DE, CH' 'PH, US' 'SG, GB' 'KR, MX' 'IE, NO' 'FR, CH' 'CS'
#  'JP, MX, US' 'CY' 'BE, DE, FR' 'FR, IR' 'LV' 'RS, CS' 'FR, US, CA'
#  'AU, IE, MX, GB' 'CA, AU' 'AM' 'CN, FR' 'DE, FR, US' 'IR, TR' 'FR, CZ'
#  'SI' 'CN, GB' 'AR, IT' 'US, CA, AU, GB' 'GB, MX, CA, IT' 'ID, MY' 'AF'
#  'DE, RO' 'UG' 'MA, SY' 'BE, FR, CH' 'FR, CA, NZ' 'DE, BE, IT' 'LB, SA'
#  'KR, CN' 'GB, TH' 'DE, NL' 'HK, CN' 'GB, CA, ES' 'SE, CA, FR' 'CY, GR'
#  'AT, DE, GB' 'AF, IN, PK, TC, AE' 'BW, BR' 'BE, CA, FR' 'CM' 'MD'
#  'SK, CZ' 'FR, IE' 'EG, SA' 'IT, US, FR' 'JP, SA' 'GB, SE' 'AR, US'
#  'PG, PK' 'BR, MX' 'AU, NZ, US' 'CA, FR, IT' 'GB, CA, US' 'BH' 'PE, ES'
#  'ES, PH, IL' 'DZ' 'AU, DE, IT' 'HR, YU' 'SG, TW' 'LT' 'JM'
#  'BG, ES, FR, GR, PL' 'RU, US' 'NG, GB' 'AT, DE, IT' 'RO, GB' 'BY, RU'
#  'ES, IT, FR' 'PL, SK' 'RU, UZ' 'PL, BE, GB' 'US, TW' 'BR, CA, US'
#  'BD, IN, NP, PK' 'BG, DE, PL' 'MY, SG, TH' 'YE' 'BY' 'FR, NE, SN'
#  'US, ES' 'ID, KR' 'DK, DE, GB' 'DE, AU, GB' 'BG, SU' 'BU' 'LK, US'
#  'US, PH' 'QA, GB, US' 'SO' 'BR, IE, ES' 'IN, IT' 'IT, DE' 'NI' 'DZ, SY'
#  'CA, JP' 'IE, GB, US' 'CR' 'MY, KR' 'TG' 'GB, VN' 'CL, GT' 'BE, CH'
#  'HK, MY' 'PL, DE' 'GB, DE, AU' 'DE, IT, ES' 'BE, DE' 'PY' 'ZW'
#  'SA, EG, AE' 'KW, LB' 'DE, CA, CH' 'MT' 'NP' 'DE, PL' 'PS' 'US, AU, JP'
#  'CA, US, FR' 'FI, FR' 'MT, GB' 'JM, US' 'DE, AT, ES, FR, IT, GB, CH'
#  'ZA, MU' 'CL, MX' 'MN' 'SY, AE' 'AU, CA, FR, US' 'ES, VE, IT'
#  'CA, DE, GB, SG' 'MY, TW' 'CN, TH' 'GB, FR, US' 'KR, TH' 'CA, HK'
#  'QA, TW' 'IR, RU, UZ' 'KZ, RU' 'DE, FR, IT, AT, ES' 'DK, NO' 'EG, AE'
#  'DK, TH' 'CN, US, FR, NZ' 'KH' 'JP, SG' 'US, AR' 'AR, CL, MX' 'GB, IN'
#  'DE, PL, RU' 'HN' 'US, CZ' 'TH, GB' 'GR, IS' 'PH, KR' 'BN' 'CO, MX'
#  'GB, DE' 'ZM' 'AT, FR, DE, IT' 'MX, PE' 'US, CN' 'FR, CA, LU' 'DK, US'
#  'DE, CA, US' 'DE, AT, FR, IT' 'IR, US' 'US, ID' 'PT, GB, ES' 'AU, CA, SG'
#  'XI, GB' 'FR, MQ' 'MK' 'AU, IN' 'DE, KR' 'FR, DE, IE' 'FR, BE'
#  'TW, SG, CN' 'DE, ES, FR' 'FJ' 'HR, RS' 'MM' 'BZ' 'AU, NL' 'CI' 'EE, US'
#  'US, SG, AU' 'PH, VE' 'CA, CO' 'AU, CA, GB' 'EG, DE' 'GB, NL' 'SZ' 'AO'
#  'BE, NL, FR' 'SY, LB' 'TR, US' 'AU, CA, US, GB' 'CA, IE' 'AU, IE' 'AW'
#  'SG, TW, HK' 'BE, FR, CA' 'VE, PE' 'KP' 'CA, IT' 'HK, SG' 'BR, CH'
#  'IR, FR, LB, HU' 'BE, GB' 'HK, CN, TW' 'GB, SG' 'CL, US' 'ZA, GB' 'GA'
#  'AE, US, FR' 'FR, DE, IN, GB, US' 'GB, RU' 'FI, SE, MX' 'CI, FR' 'FR, LU'
#  'PH, MX' 'SG, MY' 'AT, DE, ES, IT, FR' 'DE, IT, CH' 'DE, CN' 'ET'
#  'BE, LU, NL' 'IN, US' 'IL, JP' 'HR, SI' 'MK, MY' 'HR, DE' 'IN, JP' 'AN'
#  'MY, ID, SG' 'GB, MT, US, AU' 'DZ, EG, LB, SY' 'BR, DE' 'LY' 'TT' 'XI'
#  'TW, CN, HK' 'BR, PH' 'GB, IO' 'GB, TR' 'BR, IT' 'BR, IN, PT, GB, US'
#  'DE, JP' 'AU, BE, DK, IS, NL, PT, US, JP' 'BR, GB' 'IN, GB' 'AR, MX, CO'
#  'ES, CA' 'CN, KR' 'DE, NO' 'BG, US' 'FR, NL' 'US, PR' 'ME' 'EE, LT, LV'
#  'PA' 'FR, NZ' 'GH' 'MY, PH, PL, RU' 'VE, ES' 'FR, AT' 'SG, CN'
#  'BE, FI, FR' 'AT, IN' 'DZ, MA, TN' 'BR, US, IN, NG, GB' 'BR, CA, FR'
#  'AU, BE' 'KZ, RU, UA' 'GB, CZ' 'CA, IT, US' 'AR, AU, BR' 'DE, GR'
#  'SK, KR' 'DE, FR, US, GB' 'US, DE' 'SA, EG' 'CD' 'RU, EE' 'SG, TW, CN'
#  'FI, GB' 'AM, BY, KZ, MD, RU, UA' 'US, BR' 'PG' 'CN, RU' 'BF' 'LV, UA'
#  'MX, GB' 'US, DE, RO' 'IO, PK' 'MY, PH' 'BA, HR' 'GH, KE, NG, ZA, TZ'
#  'BG, DE' 'LA' 'SE, DE' 'CL, CN' 'KW, US' 'PL, RU' 'IL, US' 'ST' 'DE, YU'
#  'KW, AE' 'AR, RU' 'BE, CA' 'IE, US, FR' 'CO, DO, US' 'HK, KR' 'NL, DE'
#  'PL, CH, GB' 'BA, ME, HR, RS' 'CA, EG, ES, US' 'FR, PL' 'FR, DE, JP, ES'
#  'LB, SY, TN, AE' 'CZ, PL' 'IT, PH' 'MP' 'BE, IT' 'AE, SY' 'LV, RU'
#  'ZA, DE' 'IT, ES, VE' 'KE, ZA' 'CN, HK, TW' 'ME, RS' 'ML' 'CO, EC'
#  'AU, IT' 'US, PT' 'CA, FR, US, GB' 'ES, FR, IT' 'AD' 'BD, US'
#  'CZ, HU, PL, SK' 'CU, US' 'DK, IT' 'NO, DK, SE' 'BA, YU' 'BW'
#  'US, ES, PR' 'MX, ES, US' 'AU, GB, US, CA, NZ' 'US, NO' 'SE, US'
#  'FR, IT, GB' 'EG, IQ, SA' 'BU, MM' 'QA, PH' 'BR, PT' 'US, CA, DE, GB'
#  'IL, NL' 'ES, NL' 'US, FR, CA' 'JP, SG, CN' 'DK, GB' 'FI, FR, DE'
#  'FR, PT' 'GB, AU, CA' 'KZ, TR' 'AE, GB, US, PK, IN' 'DE, IT, AT'
#  'FR, DE, RU, GB, US' 'HU, IT' 'SA, GB' 'VU' 'SG, US' 'CZ, DE' 'EG, GB'
#  'KZ, GB' 'IE, IL' 'PE, EC' 'LU, CZ' 'IT, MX, SU' 'BE, FR, IT, CA, CH'
#  'NC' 'JP, SG, GB, US' 'GB, FR, HU, DE, IT' 'ES, DE' 'PL, FR'
#  'DE, IT, FR, GB, US' 'DE, SE, CH' 'DE, FR, CH' 'AU, PT, GB, US'
#  'DK, FI, IS, NO, SE' 'XI, PK' 'BE, DE, NL' 'CA, AU, US, GB' 'ID, JP'
#  'IT, AU, CH' 'JP, PH' 'DO, VE' 'US, CA, GB' 'VE, DO' 'CF, CN' 'BS'
#  'XC, SK']
#
#
# spoken_languages
# ['English' 'Español' 'English, 한국어/조선말, اردو' 'English, Deutsch, Español'
#  '日本語' 'Deutsch' 'English, Español' 'Français'
#  'English, Français, Pусский, Español' 'English, 한국어/조선말'
#  'Italiano, Español' 'Deutsch, Français, Lietuvių, Nederlands, English'
#  'Türkçe' '한국어/조선말' 'Español, English' 'English, Deutsch'
#  'Français, English' 'Português, Español' 'English, Türkçe'
#  'Español, English, 日本語' 'Español, English, ελληνικά, 普通话'
#  'English, 한국어/조선말, Português' 'English, Afrikaans, Íslenska'
#  'English, Português, ภาษาไทย' 'English, Dansk, Español'
#  'Español, Français, English' 'English, No Language'
#  'العربية, English, Français, Deutsch, 日本語, Pусский, Español, Türkçe'
#  'English, Română' 'Português' 'English, Français' 'Dansk'
#  '日本語, English, Deutsch'
#  'Deutsch, 广州话 / 廣州話, Dansk, Français, English, Español, svenska, Polski, Norsk, Português'
#  'Català' 'English, 日本語' 'English, Español, svenska, Italiano'
#  'עִבְרִית, Português' 'Norsk' 'English, اردو' 'Español, Català'
#  '普通话, English, 日本語, 한국어/조선말' 'ภาษาไทย' 'Pусский, English' nan
#  'Italiano, 한국어/조선말' 'Español, Italiano, Português' '普通话'
#  'English, Português' 'English, Deutsch, Română'
#  'Português, Latin, Français, English, Español, Deutsch, Italiano' 'Latin'
#  '한국어/조선말, English' 'Deutsch, English' 'Deutsch, Latin'
#  'English, Italiano' 'Français, Español' 'Dansk, svenska'
#  'English, Pусский, Español' 'العربية' '한국어/조선말, Español'
#  '한국어/조선말, ภาษาไทย' 'English, Français, Español' 'English, 普通话'
#  'English, Slovenčina' 'Italiano, Magyar, English'
#  'English, עִבְרִית, Español, Português, 日本語'
#  'Nederlands, English, Français, Pусский, Español'
#  'English, Français, Italiano, Español' '普通话, English'
#  'Deutsch, Français, English' 'English, Bahasa indonesia' 'Italiano'
#  'English, Português, Pусский' 'العربية, 한국어/조선말, Español, English'
#  'Pусский' 'English, Deutsch, Italiano'
#  'English, Français, Deutsch, Italiano, 日本語, Português, Pусский'
#  '广州话 / 廣州話, English, Español' 'English, Pусский'
#  'English, Deutsch, Polski, Pусский' 'Italiano, 日本語'
#  'English, العربية, Français, Italiano, Español, Wolof'
#  'Français, English, Italiano, Polski' 'Deutsch, Français, Pусский'
#  'Italiano, English' 'ελληνικά, English' 'English, Magyar'
#  'Español, English, Português' 'English, svenska' 'Español, Português'
#  'Íslenska' 'English, Español, 普通话'
#  'English, Français, 日本語, 한국어/조선말, Español'
#  'English, हिन्दी, 普通话, Pусский' '日本語, English'
#  '普通话, Español, English, Italiano' '한국어/조선말, ภาษาไทย, English'
#  'العربية, English, Italiano, Latin, Türkçe, ελληνικά'
#  'English, Français, Deutsch' 'Português, English'
#  'English, العربية, Deutsch, Pусский' 'English, हिन्दी, Deutsch, Español'
#  'Deutsch, Español, Français, English, 日本語, Pусский' '广州话 / 廣州話'
#  'עִבְרִית, فارسی, English' 'Deutsch, Italiano, Español'
#  'English, Nederlands, Français, ภาษาไทย' 'English, Magyar, Pусский'
#  'English, Norsk' 'Italiano, English, עִבְרִית, Polski, Français'
#  'Español, Latin' 'Dansk, Norsk, svenska' 'English, Cymraeg'
#  'Deutsch, English, Dansk, Français, Íslenska' 'English, Italiano, Latin'
#  'Norsk, English' 'English, עִבְרִית' 'Polski'
#  'العربية, Português, Español' 'English, العربية' 'Español, Français'
#  'Nederlands, Français' '한국어/조선말, Tiếng Việt' 'English, हिन्दी'
#  'English, हिन्दी, ਪੰਜਾਬੀ' 'English, Latin, Cymraeg' 'Italiano, Türkçe'
#  'English, Română, svenska' 'English, Français, Kiswahili'
#  'Français, Deutsch, English, Italiano' 'Deutsch, English, Italiano'
#  'Deutsch, Bahasa melayu, Español, English, Français'
#  'English, हिन्दी, Bahasa indonesia' 'العربية, עִבְרִית' 'svenska'
#  'Deutsch, Polski' 'English, Deutsch, Tiếng Việt'
#  '广州话 / 廣州話, English, Português' 'العربية, English' 'Tiếng Việt, English'
#  'Español, Pусский, English' 'हिन्दी' '日本語, English, Español'
#  '한국어/조선말, 日本語, English' 'Deutsch, Français' 'English, 한국어/조선말, 日本語'
#  'ελληνικά' 'Dansk, English, svenska' 'Español, Català, Français'
#  'English, suomi' 'English, Deutsch, svenska' 'Deutsch, English, Français'
#  'English, isiZulu' 'Español, English, Český'
#  'Deutsch, Español, Português' 'English, 日本語, Português'
#  'English, Deutsch, Magyar' 'English, ελληνικά, Latin' 'English, Polski'
#  'English, Norsk, Deutsch'
#  'Français, Italiano, Deutsch, Nederlands, Türkçe'
#  'English, Italiano, Português, Español' 'English, Español, Français'
#  'English, suomi, Deutsch' 'English, हिन्दी, தமிழ்' 'Polski, Português'
#  'Nederlands' 'Deutsch, English, Magyar'
#  'Türkçe, Español, Français, English, Português, Deutsch'
#  'English, العربية, svenska' 'English, Italiano, Deutsch'
#  'Français, English, Italiano' '日本語, 한국어/조선말' 'Český, English, Pусский'
#  'English, Norsk, Pусский' '普通话, 日本語' 'ελληνικά, English, Français'
#  'English, Français, Slovenčina' 'Gaeilge, 日本語' 'Deutsch, Español'
#  'Español, English, 한국어/조선말' 'Deutsch, English, Español'
#  'Italiano, Nederlands, Deutsch, Français, English, 日本語'
#  'English, Italiano, Português' 'Deutsch, Español, English'
#  'suomi, Français, Pусский' 'Magyar, English'
#  'English, 普通话, Français, 日本語' 'English, Français, Deutsch, Pусский'
#  'English, Italiano, ภาษาไทย' 'עִבְרִית, English'
#  'English, Deutsch, Norsk, svenska'
#  'Latin, Español, English, Italiano, Français'
#  'English, Español, Português' 'Dansk, English, Deutsch, Norsk'
#  'Latin, Español, Italiano, English' 'English, Italiano, 日本語'
#  'English, हिन्दी, Italiano' 'Český, English' 'Galego'
#  'English, svenska, Norsk' 'English, Español, Italiano'
#  'العربية, English, Français' 'shqip, 普通话, Dansk, English, 日本語, Srpski'
#  'Français, English, Italiano, svenska' 'Slovenčina, Español'
#  'Afrikaans, English' 'svenska, English' 'ελληνικά, Türkçe'
#  'Cymraeg, English' 'Pусский, Український' 'Türkçe, English' 'Magyar'
#  'Český, English, Français, Deutsch, עִבְרִית, Pусский'
#  'Français, English, العربية' 'English, Kinyarwanda'
#  'Polski, English, Español' 'Español, Pусский'
#  'Deutsch, Français, Español' 'Deutsch, Italiano'
#  'English, Français, Türkçe' 'English, Español, Português, Français'
#  'English, Français, Deutsch, Español' 'English, Polski, Deutsch'
#  'English, Italiano, Español' 'English, Deutsch, עִבְרִית'
#  'Deutsch, Türkçe' 'ქართული, Español' 'Český' 'Español, Deutsch'
#  'العربية, English, Français, Deutsch, Magyar, 日本語, Pусский, Español'
#  '日本語, Italiano' 'English, Deutsch, Polski' 'English, Dansk'
#  'العربية, 日本語, Português' 'العربية, English, עִבְרִית, Norsk, Español'
#  '广州话 / 廣州話, 普通话' 'Català, Español' 'Română, 日本語'
#  'Français, English, Deutsch' 'English, Français, Português, Deutsch'
#  'Dansk, Deutsch' 'Polski, Français' 'Dansk, Français'
#  'العربية, English, Français, Polski' 'Italiano, Português, English'
#  'Français, Italiano'
#  '普通话, 한국어/조선말, Bahasa indonesia, English, 日本語, ภาษาไทย'
#  'العربية, Polski, Deutsch, Français, Español, Italiano, English'
#  'Český, English, Slovenčina' 'العربية, 日本語' 'Română'
#  'English, 日本語, Français' 'English, Italiano, Português, Pусский, Español'
#  'Norsk, svenska' '普通话, English, فارسی' '日本語, Deutsch' 'No Language'
#  'Dansk, English, svenska, Norsk' 'Italiano, Deutsch'
#  'Pусский, Français, English'
#  'עִבְרִית, Français, English, Nederlands, Deutsch' 'български език'
#  'Italiano, English, Español' 'עִבְרִית' 'English, Français, Português'
#  'Português, Español, English' 'English, ภาษาไทย' 'Dansk, svenska, Latin'
#  'ภาษาไทย, 普通话' 'English, Nederlands, Dansk, Deutsch, Français, svenska'
#  'English, Français, Polski' 'Cymraeg, Français' '日本語, Português'
#  'English, 日本語, Pусский' 'עִבְרִית, Español' 'हिन्दी, தமிழ், తెలుగు'
#  'English, Français, Italiano' 'Español, Français, English, Latin'
#  'English, Afrikaans' 'Pусский, Nederlands, English, Lietuvių'
#  'English, हिन्दी, اردو' '普通话, 한국어/조선말' 'English, Český, Deutsch'
#  'Hrvatski, Español' 'Deutsch, Polski, Pусский'
#  'English, 한국어/조선말, Español' 'Français, Español, English'
#  'العربية, Dansk, English, Norsk, svenska' 'Dansk, English, Italiano'
#  'Český, English, Español' 'Cymraeg' 'Deutsch, English, Italiano, Norsk'
#  'हिन्दी, English' 'English, Español, Italiano, Deutsch, Français'
#  'Deutsch, English, Italiano, 한국어/조선말, Español' '普通话, Pусский'
#  'Français, Català, Português, Italiano' 'Italiano, Português'
#  '普通话, English, Italiano, Español' 'English, Slovenčina, Český'
#  'English, Français, svenska' 'Français, Nederlands' 'Latin, 日本語'
#  'Français, 日本語' 'English, Português, Español'
#  'Français, Italiano, Deutsch' 'Italiano, Français, English'
#  'Italiano, Română' 'Italiano, suomi, Français' 'Kiswahili, English'
#  '普通话, Bahasa melayu' 'Pусский, Español' 'Srpski'
#  'English, Pусский, Český' 'العربية, Español, English'
#  'English, Français, 日本語' 'English, Český' '日本語, ภาษาไทย' 'Dansk, English'
#  'Español, Türkçe' 'العربية, Pусский, Français, English'
#  'বাংলা, हिन्दी, English' 'suomi' 'العربية, Español' 'Deutsch, 日本語'
#  'English, العربية, עִבְרִית, Italiano, Français' 'Hrvatski'
#  'euskera, Español' 'Deutsch, Magyar' 'Español, Français, Português'
#  'தமிழ்' 'فارسی' '한국어/조선말, English, اردو' 'English, Türkçe, ελληνικά'
#  'Deutsch, English, Português' 'Français, Polski'
#  'English, ελληνικά, 한국어/조선말' 'English, Deutsch, اردو'
#  'Afrikaans, English, Kiswahili, isiZulu' '广州话 / 廣州話, English, 普通话'
#  'Norsk, English, Français, Magyar'
#  'English, Español, Français, Português'
#  'English, Český, Italiano, svenska' 'Français, Dansk' 'বাংলা'
#  'Français, Norsk' 'English, Italiano, Deutsch, Español'
#  'Türkçe, Français' 'Dansk, Norsk' 'English, Nederlands'
#  'Français, Deutsch, Italiano, Español'
#  'Deutsch, Français, English, Español, Italiano, Português'
#  'Bahasa indonesia' 'Dansk, Eesti, suomi, English, Norsk, svenska'
#  'English, Íslenska, svenska, Dansk' 'English, Italiano, Français'
#  'Deutsch, English, Norsk' 'suomi, English, Pусский, svenska'
#  'Deutsch, Français, Italiano, Slovenčina, Český, Magyar' 'العربية, اردو'
#  'বাংলা, English, हिन्दी' 'Deutsch, English, Français, Português'
#  'Deutsch, Français, Italiano' 'English, Italiano, Magyar'
#  'shqip, Hrvatski, English, Srpski' 'Bahasa melayu'
#  'English, Dansk, Deutsch, Norsk, svenska' '한국어/조선말, 日本語'
#  'Magyar, Lietuvių, Polski'
#  'Español, English, Pусский, Deutsch, Polski, Italiano, پښتو, Český, ελληνικά, 한국어/조선말, 普通话'
#  'Latviešu, Pусский' 'Deutsch, Español, English, Italiano, Français'
#  'English, Español, 日本語' 'English, Italiano, اردو' 'Español, Český'
#  '普通话, Bahasa indonesia, Pусский' 'Français, Pусский' '普通话, ภาษาไทย'
#  'हिन्दी, ਪੰਜਾਬੀ' 'Español, English, العربية'
#  'English, Íslenska, Norsk, svenska' 'English, Polski, svenska'
#  'বাংলা, हिन्दी' 'Nederlands, 日本語' 'Český, English, Deutsch, Español'
#  'Français, Türkçe' 'Galego, Español' 'Magyar, English, Deutsch'
#  'English, Italiano, Pусский, ελληνικά' 'Deutsch, English, עִבְרִית'
#  'Polski, Pусский' 'ภาษาไทย, 한국어/조선말' 'Deutsch, English, 한국어/조선말'
#  'English, Deutsch, Español, Italiano'
#  'Español, Pусский, English, Français, Deutsch'
#  '한국어/조선말, 日本語, English, Italiano' 'Dansk, Español'
#  'Český, Deutsch, Polski' 'العربية, Deutsch, Nederlands' 'Український'
#  'English, Magyar, Italiano' 'العربية, Français, English'
#  'Español, Italiano' 'עִבְרִית, Nederlands, English'
#  'English, Norsk, svenska' 'తెలుగు' 'Deutsch, Pусский' 'Français, Deutsch'
#  'العربية, Türkçe' 'Deutsch, Dansk' 'Azərbaycan, Türkçe' '日本語, Español'
#  'English, Français, Bahasa indonesia' 'Bahasa indonesia, English'
#  'Polski, Pусский, Český, English' 'Español, 日本語' '日本語, Italiano, Deutsch'
#  'Galego, Português' 'العربية, Italiano' 'English, தமிழ், తెలుగు, हिन्दी'
#  'English, עִבְרִית, Română, Français' 'English, Deutsch, suomi'
#  'English, Français, Český' 'English, Français, Pусский' '한국어/조선말, Türkçe'
#  'English, suomi, svenska' 'Deutsch, Český, Magyar'
#  'বাংলা, हिन्दी, ?????, தமிழ்' 'हिन्दी, اردو'
#  'English, Français, Deutsch, Italiano, Polski, Pусский, Tiếng Việt'
#  'Deutsch, English, Español, Français'
#  'English, עִבְרִית, Hrvatski, 한국어/조선말, Italiano, Português, Español'
#  '普通话, English, Français, Italiano, Español' 'Français, 日本語, English'
#  'Český, Français, Deutsch' 'Français, suomi' 'English, Český, Français'
#  'English, svenska, ภาษาไทย' 'Español, English, Italiano'
#  '日本語, 普通话, 한국어/조선말' 'български език, Bosanski, Hrvatski, Srpski'
#  'English, Latin' 'English, Français, Deutsch, Italiano, Español'
#  'Hrvatski, Pусский, Український' 'English, Română, Español'
#  'Deutsch, Português, 日本語' '广州话 / 廣州話, 普通话, English, 日本語, ภาษาไทย'
#  'Slovenčina' '普通话, Français, Italiano' 'Afrikaans'
#  'العربية, English, Deutsch, svenska' 'English, Türkçe, فارسی'
#  'English, svenska, Deutsch' 'English, فارسی, Türkçe' 'Deutsch, svenska'
#  '普通话, 广州话 / 廣州話' 'қазақ, Pусский' 'English, Polski, svenska, suomi'
#  'Íslenska, Français' 'English, Tiếng Việt'
#  'English, Français, Italiano, Português' 'English, Srpski'
#  'Português, Français' 'Français, 普通话, English' 'Český, Slovenčina'
#  'English, Pусский, svenska' 'Bahasa melayu, English, Bahasa indonesia'
#  'English, Nederlands, svenska, suomi' 'Deutsch, English, Íslenska' 'اردو'
#  'Srpski, Türkçe' 'shqip, English, Hrvatski, Srpski'
#  'Dansk, English, Français, Deutsch, Norsk, svenska'
#  'English, Dansk, svenska' 'Français, Nederlands, Deutsch, English'
#  'Català, Español, English' 'Español, עִבְרִית, English'
#  'Deutsch, English, Nederlands, Polski' 'Español, svenska'
#  'العربية, English, Español' 'العربية, Français' 'English, ελληνικά'
#  'العربية, English, עִבְרִית' 'Français, 日本語, Italiano'
#  'Deutsch, English, Український, Bahasa indonesia, 日本語, 한국어/조선말'
#  'Lietuvių, Português' 'English, हिन्दी, ?????, தமிழ்' 'Pусский, العربية'
#  'Deutsch, English, Nederlands' 'svenska, suomi'
#  'English, Hausa, Èdè Yorùbá' 'العربية, فارسی'
#  'العربية, עִבְרִית, English' 'Pусский, Türkçe'
#  'Español, Italiano, Français' '?????' 'Dansk, Deutsch, svenska'
#  'Català, English, Español' 'English, العربية, 한국어/조선말, Français, 日本語'
#  'Français, Português' 'Český, suomi' 'ਪੰਜਾਬੀ, اردو'
#  'Deutsch, English, Español, Français, Italiano, svenska'
#  'English, Český, Slovenčina' 'Tiếng Việt'
#  'Deutsch, Français, Español, English' 'Italiano, Português, עִבְרִית'
#  '普通话, Français, Português, Český' 'English, Deutsch, Français'
#  'Hrvatski, Srpski' 'English, Nederlands, Deutsch' 'English, Gaeilge'
#  '普通话, English, 한국어/조선말' 'English, suomi, Magyar' 'বাংলা, English'
#  'English, فارسی' 'עִבְרִית, Français, English' 'العربية, Français, 日本語'
#  'العربية, Nederlands' '普通话, English, Bahasa melayu' 'Français, Latin'
#  'Italiano, Français' 'العربية, English, हिन्दी, پښتو, اردو'
#  'suomi, Italiano, Pусский, svenska' 'Deutsch, suomi, Español, svenska'
#  'اردو, English' 'Italiano, Latin' 'English, svenska, Türkçe' 'Eesti'
#  'English, Français, Deutsch, Polski, Português, Español'
#  'العربية, Français, עִבְרִית' 'Dansk, English, suomi, Norsk, svenska'
#  'English, हिन्दी, ?????' 'Èdè Yorùbá' 'English, 日本語, Español'
#  'हिन्दी, ?????' 'Català, English, suomi, svenska' 'Bosanski'
#  'Pусский, svenska' 'العربية, हिन्दी, اردو' 'Tiếng Việt, 普通话'
#  'English, Français, Italiano, Český, Deutsch' '普通话, Español, 日本語'
#  'English, svenska, Pусский' 'English, Español, svenska'
#  'Český, English, Magyar' 'Magyar, Italiano' 'සිංහල'
#  'العربية, English, Français, Deutsch' 'English, Français, ελληνικά'
#  'Český, English, Italiano' 'Gaeilge, English'
#  'Polski, Français, suomi, Nederlands, Português, 日本語, svenska, Norsk, Español, Italiano, English, 广州话 / 廣州話'
#  'English, العربية, Français, Italiano' 'Français, Hrvatski'
#  '普通话, English, Nederlands' 'Français, English, Italiano, Magyar'
#  '한국어/조선말, ozbek' 'Azərbaycan, Pусский' 'ქართული' 'हिन्दी, தமிழ்'
#  'Deutsch, Nederlands' 'Bosanski, Hrvatski, Srpski, Slovenščina'
#  'العربية, हिन्दी' 'Nederlands, English, Español'
#  'English, हिन्दी, தமிழ், తెలుగు' 'Deutsch, Français, Nederlands'
#  'Deutsch, English, Français, 日本語' 'Dansk, English, Norsk'
#  'English, Bahasa melayu' 'English, 日本語, 普通话' 'Français, Wolof'
#  'English, Kiswahili' 'English, தமிழ்' 'shqip'
#  'Bosanski, English, Italiano, Slovenščina'
#  'Deutsch, Français, English, 日本語' 'English, suomi, Eesti'
#  'English, български език, Français, Hrvatski, Srpski, Español'
#  'Français, Hrvatski, Português, English' '广州话 / 廣州話, 普通话, English'
#  'English, ภาษาไทย, Türkçe' 'Lietuvių, Pусский'
#  'Deutsch, English, Français, Italiano, Español' 'Français, עִבְרִית'
#  'English, 日本語, हिन्दी, Español, 한국어/조선말, Português'
#  'Français, Tiếng Việt' 'தமிழ், 普通话, العربية, 한국어/조선말, हिन्दी'
#  'Nederlands, English, Français, Deutsch, Português, Pусский, Español, Український'
#  'No Language, Português' 'Bosanski, Srpski' 'suomi, Dansk'
#  'English, Français, Deutsch, svenska' 'English, Español, Français, Český'
#  '普通话, Italiano, 日本語, ภาษาไทย' 'English, Deutsch, Pусский, Español'
#  'English, 日本語, Deutsch' 'English, suomi, Español' 'English, 日本語, 한국어/조선말'
#  'Français, 한국어/조선말' 'suomi, svenska' 'English, Deutsch, Cymraeg'
#  'Český, Français' '한국어/조선말, 普通话, svenska, English, 广州话 / 廣州話'
#  'English, Español, 한국어/조선말' 'Deutsch, English, Gaeilge, Nederlands'
#  'Pусский, Deutsch' 'Français, English, Pусский' 'Kiswahili'
#  'العربية, English, Français, فارسی' 'Italiano, 日本語, English'
#  'български език, English' 'Pусский, suomi' 'euskera'
#  'English, Dansk, svenska, Deutsch' '普通话, Español' 'English, ਪੰਜਾਬੀ, اردو'
#  'English, Français, ελληνικά, Türkçe' 'Español, ภาษาไทย' 'Bokmål, Norsk'
#  'Dansk, Pусский, svenska' 'ภาษาไทย, English'
#  '广州话 / 廣州話, Bahasa indonesia, English, Bahasa melayu, ภาษาไทย, Tiếng Việt'
#  'English, Český, Français, Italiano, Magyar, Deutsch, Nederlands, Português, Español'
#  'Latviešu' 'English, Français, Srpski' 'Deutsch, Français, 日本語'
#  'עִבְרִית, Deutsch, Français, English' 'Deutsch, Magyar, English'
#  'Deutsch, فارسی' '普通话, Nederlands' 'Deutsch, suomi'
#  'Afrikaans, English, Français' '普通话, Slovenčina, English, Pусский, Český'
#  'বাংলা, தமிழ்' 'English, Deutsch, Pусский'
#  'English, Español, 普通话, Français, Magyar, Italiano, Polski, Português, Pусский, Český'
#  'English, 普通话, Bahasa melayu' 'Français, Český' 'English, svenska, Dansk'
#  'Slovenščina' 'English, Magyar, Deutsch' 'Český, Deutsch'
#  'English, 普通话, Français'
#  'العربية, Dansk, English, Français, Español, svenska'
#  'العربية, English, Français, Deutsch, 한국어/조선말, Español, ภาษาไทย, Türkçe'
#  'ozbek, Türkçe' 'Dansk, svenska, Norsk' 'English, 普通话, 한국어/조선말'
#  'Français, Italiano, English' 'Català, 普通话' 'Deutsch, English, Srpski'
#  'Hausa, 日本語' '普通话, 한국어/조선말, Español, English, Português' 'shqip, English'
#  'Deutsch, English, 日本語, Português' 'English, Türkçe, 日本語'
#  'العربية, English, Français, Hrvatski, Español' 'suomi, English'
#  'Bosanski, Hrvatski, English, Deutsch, Srpski' 'اردو, हिन्दी'
#  'Dansk, English, Deutsch' '普通话, Italiano' 'Deutsch, suomi, svenska'
#  'Bosanski, Hrvatski, Srpski'
#  'Deutsch, English, suomi, Norsk, Pусский, svenska' 'Slovenčina, Český'
#  'English, العربية, Français' '日本語, suomi'
#  'Deutsch, English, Français, Pусский' 'עִבְרִית, العربية'
#  'Français, Deutsch, Italiano'
#  'Deutsch, Español, English, Português, Français'
#  'Hrvatski, Italiano, Srpski' 'English, Hrvatski'
#  'Hrvatski, English, Magyar, Polski, Português, Español'
#  'Italiano, English, Français' 'English, Bahasa indonesia, 한국어/조선말'
#  'Nederlands, English, suomi' 'Deutsch, Český' 'עִבְרִית, Pусский'
#  'اردو, العربية' 'English, 한국어/조선말, ภาษาไทย' 'Français, Srpski'
#  '普通话, English, Português, Pусский' 'العربية, 普通话, English'
#  'English, Gaeilge, Cymraeg' 'Bahasa melayu, தமிழ்'
#  'English, Bahasa indonesia, Bahasa melayu'
#  'Polski, Український, Français' 'עִבְרִית, Français' 'Lietuvių'
#  'Afrikaans, English, isiZulu' 'Deutsch, English, Português, Español'
#  'Bosanski, Hrvatski, English, Srpski' 'Český, Pусский'
#  'Nederlands, English' 'Nederlands, English, 日本語' 'Italiano, Polski'
#  'English, Eesti' 'English, Español, Deutsch, Pусский'
#  '广州话 / 廣州話, 普通话, English, 日本語' 'English, हिन्दी, No Language'
#  'English, Український' 'English, Hrvatski, Deutsch' 'isiZulu'
#  'български език, Deutsch, Polski'
#  'العربية, 普通话, English, Français, Deutsch, 日本語, Polski, Português, Pусский, Español'
#  'Français, 普通话' 'English, עִבְרִית, Pусский' 'Český, Italiano'
#  'български език, Pусский' 'Deutsch, English, Nederlands, Pусский'
#  'العربية, Français, 普通话, Español, English' 'English, Íslenska'
#  'हिन्दी, తెలుగు' 'Somali' 'English, Český, Dansk, Slovenčina'
#  'Pусский, suomi, svenska' 'Español, Galego'
#  'Deutsch, Español, Français, Italiano, Română, Український'
#  'Français, Český, English' 'беларуская мова, Deutsch, Pусский'
#  'Português, 한국어/조선말' 'ਪੰਜਾਬੀ' 'Español, English, Pусский'
#  'اردو, العربية, हिन्दी' 'English, Français, සිංහල' 'Gaeilge'
#  'Magyar, Deutsch' 'suomi, Pусский' 'Český, English, Français, Deutsch'
#  'Slovenščina, 日本語' 'Český, 日本語' 'English, Latviešu'
#  'English, Español, Deutsch, Türkçe, suomi' 'پښتو, اردو' 'English, Malti'
#  'English, עִבְרִית, العربية' 'English, Eesti, svenska'
#  'English, Deutsch, ελληνικά'
#  'Deutsch, English, Español, Français, Italiano'
#  'हिन्दी, Pусский, Український' 'Deutsch, العربية, 普通话'
#  'Deutsch, 日本語, English' 'Azərbaycan'
#  'Deutsch, English, Français, Italiano' 'தமிழ், తెలుగు'
#  'Nederlands, English, Norsk' 'Italiano, Nederlands'
#  'English, ελληνικά, Türkçe' 'English, български език, Pусский'
#  'Deutsch, English, 日本語' 'English, Magyar, Srpski' 'Nederlands, فارسی'
#  'English, עִבְרִית, ภาษาไทย' 'English, বাংলা'
#  'English, Pусский, Український' 'العربية, English, हिन्दी'
#  '广州话 / 廣州話, English' 'Magyar, Deutsch, Pусский, Français'
#  'Èʋegbe, Français' 'العربية, English, svenska'
#  'العربية, English, Français, Türkçe'
#  'Español, English, Italiano, Português'
#  'беларуская мова, Lietuvių, Polski, Pусский' 'Bokmål' 'Hrvatski, Deutsch'
#  '한국어/조선말, English, Français' 'suomi, Français, Pусский, svenska'
#  'English, 日本語, 普通话, 한국어/조선말' 'Dansk, English, Deutsch, Norsk, svenska'
#  'English, العربية, suomi, Somali'
#  'Deutsch, Français, Italiano, Nederlands, English'
#  '?????, English, हिन्दी' '普通话, English, Italiano'
#  'Deutsch, English, Pусский, Türkçe, Український'
#  'ภาษาไทย, Tiếng Việt, English' 'Français, English, 日本語'
#  'Dansk, Español, English, Norsk' 'Français, Pусский, Srpski'
#  'English, Français, Nederlands' 'shqip, English, Français, Deutsch'
#  'Nederlands, English, Français, Deutsch' 'English, ?????'
#  'Español, Norsk' 'Deutsch, ελληνικά' 'Český, No Language' 'Malti'
#  'Pусский, English, 한국어/조선말' 'বাংলা, हिन्दी, ?????, தமிழ், తెలుగు'
#  'Português, Pусский' '普通话, English, 广州话 / 廣州話' 'shqip, English, Italiano'
#  'Nederlands, Türkçe' 'Bosanski, Italiano, Srpski'
#  'ქართული, Español, Pусский' 'English, فارسی, Pусский' 'Deutsch, Română'
#  'қазақ' 'Nederlands, Français, Deutsch' 'Afrikaans, Français, Nederlands'
#  'Français, Nederlands, Türkçe' 'Hrvatski, Slovenščina'
#  'English, Deutsch, Pусский, Srpski' 'English, 日本語, ภาษาไทย'
#  'Deutsch, English, Pусский' 'English, עִבְרִית, Português'
#  'English, Magyar, Română' 'English, Nederlands, Kiswahili' '한국어/조선말, 普通话'
#  'العربية, Deutsch' 'ქართული, English' '普通话, English, Français, Español'
#  'English, Italiano, Srpski' 'Eesti, Pусский'
#  'English, Français, Nederlands, Türkçe'
#  'English, 普通话, Português, Pусский' 'Wolof' 'Nederlands, Pусский'
#  'Français, English, Italiano, Português, Español' 'Dansk, English, 普通话'
#  'Türkçe, Cymraeg' 'Català, Español, Galego' 'English, Français, Magyar'
#  'Français, svenska'
#  'العربية, 普通话, Français, Italiano, қазақ, فارسی, Pусский, Türkçe'
#  'Nederlands, Español' 'Nederlands, English, Français, Português, Español'
#  '日本語, 普通话' 'پښتو' 'Español, Nederlands, English'
#  'Nederlands, Český, English'
#  'English, हिन्दी, עִבְרִית, Português, ภาษาไทย' 'Latin, Magyar'
#  'Español, English, Português, Pусский'
#  'বাংলা, English, हिन्दी, ?????, தமிழ், తెలుగు'
#  'English, Italiano, svenska' 'English, 日本語, Bahasa melayu'
#  'ελληνικά, Pусский, Türkçe' 'suomi, Français' 'English, Deutsch, 한국어/조선말'
#  '普通话, Bahasa melayu, English' 'Azərbaycan, فارسی'
#  'English, Bahasa melayu, தமிழ், ภาษาไทย'
#  'English, Italiano, Deutsch, Français'
#  'العربية, English, Français, עִבְרִית' 'हिन्दी, ?????, தமிழ், తెలుగు'
#  '普通话, English, Bahasa melayu, தமிழ்' 'Français, English, Magyar'
#  'English, ?????, Tiếng Việt' 'English, Deutsch, 日本語'
#  'English, 한국어/조선말, Tiếng Việt' 'Český, English, Deutsch'
#  'Pусский, Latviešu' 'Deutsch, Pусский, Srpski'
#  'Český, English, Deutsch, Polski' 'Deutsch, English, suomi'
#  'English, हिन्दी, తెలుగు' 'English, Pусский, Français'
#  'Deutsch, Bosanski, Hrvatski' 'Français, Nederlands, Kiswahili'
#  'Français, العربية' 'suomi, 한국어/조선말' 'Deutsch, Norsk' 'Český, 普通话'
#  'English, Français, Gaeilge, Tiếng Việt, Cymraeg'
#  'Deutsch, English, Polski' '日本語, 广州话 / 廣州話'
#  'Deutsch, English, Nederlands, Español' 'العربية, Français, Italiano'
#  'Español, Português, Română, Türkçe' 'English, Esperanto' 'ozbek'
#  '普通话, Bahasa melayu, தமிழ்' 'English, हिन्दी, ?????, தமிழ், తెలుగు'
#  'தமிழ், English' 'Bahasa indonesia, 한국어/조선말'
#  'Bosanski, Hrvatski, Italiano, Srpski' 'English, Slovenščina'
#  'Dansk, English, suomi, Íslenska, Norsk, svenska' 'Pусский, Srpski'
#  'български език, Český, Magyar, Deutsch, Polski, Pусский, Slovenčina'
#  'Pусский, Español, Український' '广州话 / 廣州話, 한국어/조선말, 普通话'
#  'Íslenska, English' 'English, Italiano, Nederlands' 'हिन्दी, پښتو'
#  '普通话, Italiano, ภาษาไทย, Tiếng Việt' 'Deutsch, English, हिन्दी, Italiano'
#  '한국어/조선말, Français, English' 'svenska, suomi, Türkçe'
#  'Deutsch, Français, Italiano, 日本語, Polski, Português, Pусский, Español, English'
#  'Español, euskera' '日本語, Nederlands' 'Dansk, English, Español'
#  'Deutsch, Français, Türkçe' '日本語, ภาษาไทย, 한국어/조선말'
#  'Deutsch, Français, 普通话' 'Català, English, Français, Español'
#  'Český, Polski' 'العربية, English, Bahasa indonesia, 日本語, 普通话, 한국어/조선말'
#  'Français, Nederlands, English' 'Français, Italiano, Português, Español'
#  '普通话, English, 日本語' 'български език, Deutsch' 'العربية, English, اردو'
#  'Deutsch, English, Pусский, Türkçe' 'Český, Español' 'Český, Tiếng Việt'
#  'Magyar, Türkçe' 'English, 普通话, 广州话 / 廣州話' 'Pусский, Français'
#  'Polski, English, Nederlands, Français'
#  'English, 日本語, 한국어/조선말, Português, Español'
#  'Hrvatski, Srpski, Slovenščina' 'Italiano, Deutsch, Nederlands'
#  'Português, svenska, Deutsch' 'Español, Italiano, Pусский'
#  '普通话, Français' 'Français, Esperanto, English' 'svenska, Deutsch'
#  'English, беларуская мова, қазақ, Pусский' 'No Language, svenska'
#  'Nederlands, svenska' 'suomi, Pусский, svenska' 'ελληνικά, Italiano'
#  'العربية, English, suomi, Italiano' 'Deutsch, Français, Slovenčina'
#  'Afrikaans, Bahasa indonesia, ozbek' 'Bosanski, Hrvatski'
#  'العربية, English, 한국어/조선말' 'Nederlands, Magyar'
#  'English, Français, Italiano, Español, Türkçe' 'Bahasa indonesia, 日本語'
#  'Norsk, Bokmål' 'Deutsch, English, Français, ?????' 'English, қазақ'
#  'ਪੰਜਾਬੀ, हिन्दी' '日本語, No Language' 'Bahasa melayu, English'
#  'Deutsch, English, 日本語, Español' 'shqip, Český'
#  'Dansk, English, Український']
#
#
# production_companies
# ['Revolution Sun Studios, Television 360, Generator Entertainment, Bighead Littlehead'
#  'Vancouver Media' '21 Laps Entertainment, Monkey Massacre Productions'
#  ... 'Fly on the Wall Entertainment, Endemol Shine North America'
#  'HEY Play(MM)' 'ARTE, Zorba Production, Volos Films, TaiwanPlus']
#
#
# production_countries
# ['United Kingdom, United States of America' 'Spain'
#  'United States of America' ... 'France, South Africa'
#  'Bulgaria, Czech Republic, Slovakia' 'France, Taiwan']
#
#
# episode_run_time
# [   0   70   42   45   43   44   22   52   60   58   50   25   53   30
#    24   90   47   35   26   57   34   55   41   65   39  130   40   10
#    21   11   80   77   36   46   23   48   56   75   59   28   27   81
#    54   49   33   51  120   20   66   12  105   72  201   15    7  100
#    93   64   31   18    8   85    4   14   78   37   62   97    6   67
#    92   32   17   38    3    5   88   29  157   69    2   95   13  172
#    86   91   61   76    9  160   87   68  118   63  140  184  170  519
#    84  337   89  177  121  182   74  186  142  180  150   71  195   99
#   124   73  540  185   94  175  240   82  288  167  162  110  217   96
#   168   19  156  206  155  126  200  132  178  102    1   16  103  141
#    79  123  125  173  264  135  239  133  300  192  215  315  127  179
#   390  139  440   83  111  115  165  131  290  270  117  106  112  277
#   411  210  108 1080  194  114  325  116  366  360  275  284  620  363
#   245  611  230  480  238  500  308  188  138  630  342  306  333  287
#   225  205  107  660  570  389  348  189  260  576  145  191  154  174
#   161 1256  334  151  355  136  190  148  181  292  113   98  104  258
#   129  495 1472  176  263  616  143 2006  624  218  252  228  362  159
#   216  183  144  273  400  354  705  816  750  208  324  741  610 1024
#   516  650  423  204  384  255  949  207  171  826  212  410  412  122
#   541  282  220  780 1040  280  981  404  916  128  369 2280  418  234
#   153  520  344  297  364  704  372  134  313  229  465  855  332 1440
#   515  676  235  196  310  720  164  491  336 1205  396  169  350 1650
#   254  371  346 1110 4125  383  256  416  453  224  655  450  477  147
#  1150  301 1200  420  109  137  227  146  193  464 1350  152  232  533
#   870  376  262  484  330  149  550  265 1560  374  237  424  680 2016
#   285  312  810  119  246  250  596 1000  600  223 1500 1993  575  295
#   353  221  351  197  259  535  357  845 2394  790  757  696  341  470
#   824 6032  900  242  319 1305  761  305  392  293  564 1425  303  712
#   226  523  166  219  756  326  640  793 1210  367  321 2024  322  368
#   544 1536  577 5254 1612  573 1187 1480  672 1630  413  415  497  187
#   251  569  557  407  726 1400 1390 2450]

# %%
# ------------------------
# TV Series

tvseries_df = tvseries_df.drop(['backdrop_path', 'homepage', 'poster_path', 'overview', 'tagline'], axis=1)
tvseries_df = tvseries_df.dropna(subset=tvseries_df.columns.difference(['last_air_date']))

# get year later than 1990
tvseries_df['first_air_date'] = pd.to_datetime(tvseries_df['first_air_date'])
tvseries_df['last_air_date'] = pd.to_datetime(tvseries_df['last_air_date'])
tvseries_df = tvseries_df[tvseries_df['first_air_date'].dt.year >= 1990]


tvseries_df.loc[tvseries_df["origin_country"] == "XC", "origin_country"] = "CZ"

for ccode in ["YU", "XG", "XK", "SU"]:
    tvseries_df.drop(tvseries_df[tvseries_df.origin_country == ccode].index, inplace=True)
# tvseries_df = tvseries_df.dropna(subset=tvseries_df.columns.difference(['last_air_date']), how='all')
# tvseries_df = tvseries_df.dropna()

# %%
# tvseries_df.loc[tvseries_df["origin_country"] == "XC", "origin_country"] = "CZ"
tvseries_df["origin_country"].isin(["YU", "XG", "XK", "SU"]) == True
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 166307    False
# 166319    False
# 166329    False
# 166360    False
# 166361    False
# Name: origin_country, Length: 15186, dtype: bool

# %%
cleaned_file_name = "data/cleaned_TMDB_tv_dataset.csv"
tvseries_df.to_csv(cleaned_file_name, date_format='%Y-%m-%d')

cleaned_df = pd.read_csv(cleaned_file_name)
print(len(cleaned_df))
# Out:
# 15186

# %%
tvseries_df = cleaned_df
print("After clean up")
print("Rows: ", len(tvseries_df))
print("Columns: ", len(tvseries_df.columns))
# Out:
# After clean up
# Rows:  15186
# Columns:  25

# %%
tvseries_df.isna().sum()
tvseries_df['first_air_date'] = pd.to_datetime(tvseries_df['first_air_date'], format='%Y-%m-%d')
tvseries_df[tvseries_df['first_air_date'].dt.year >= 1990]
# tvseries_df
# Out:
#        Unnamed: 0      id                                       name  \
# 0               0    1399                            Game of Thrones
# 1               1   71446                                Money Heist
# 2               2   66732                            Stranger Things
# 3               3    1402                           The Walking Dead
# 4               4   63174                                    Lucifer
# ...           ...     ...                                        ...
# 15181      166307  237992                  Frozen in Time: Flashback
# 15182      166319  238974                                 Valdes Jul
# 15183      166329  238688                   Doraleous and Associates
# 15184      166360  239216                                BPM Ecstasy
# 15185      166361  239217  Génération 2008 : qui seront-ils demain ?
#
#        number_of_seasons  number_of_episodes original_language  vote_count  \
# 0                      8                  73                en       21857
# 1                      3                  41                es       17836
# 2                      4                  34                en       16161
# 3                     11                 177                en       15432
# 4                      6                  93                en       13870
# ...                  ...                 ...               ...         ...
# 15181                  1                   8                en           0
# 15182                  1                   1                da           0
# 15183                  1                  50                en           0
# 15184                  1                   4                fr           0
# 15185                  1                  10                fr           0
#
#        vote_average  adult first_air_date  ...            status  \
# 0             8.442  False     2011-04-17  ...             Ended
# 1             8.257  False     2017-05-02  ...             Ended
# 2             8.624  False     2016-07-15  ...  Returning Series
# 3             8.121  False     2010-10-31  ...             Ended
# 4             8.486  False     2016-01-25  ...             Ended
# ...             ...    ...            ...  ...               ...
# 15181         0.000  False     2021-02-20  ...             Ended
# 15182         0.000  False     2023-12-01  ...  Returning Series
# 15183         0.000  False     2012-08-13  ...             Ended
# 15184         0.000  False     2023-11-14  ...             Ended
# 15185         0.000  False     2020-11-25  ...     In Production
#
#                                             genres  \
# 0      Sci-Fi & Fantasy, Drama, Action & Adventure
# 1                                     Crime, Drama
# 2                 Drama, Sci-Fi & Fantasy, Mystery
# 3      Action & Adventure, Drama, Sci-Fi & Fantasy
# 4                          Crime, Sci-Fi & Fantasy
# ...                                            ...
# 15181                 Documentary, Reality, Family
# 15182                                 Kids, Family
# 15183          Animation, Comedy, Sci-Fi & Fantasy
# 15184                                  Documentary
# 15185                         Documentary, Reality
#
#                          created_by  languages                   networks  \
# 0         David Benioff, D.B. Weiss         en                        HBO
# 1                         Álex Pina         es          Netflix, Antena 3
# 2          Matt Duffer, Ross Duffer         en                    Netflix
# 3                    Frank Darabont         en                        AMC
# 4                       Tom Kapinos         en               FOX, Netflix
# ...                             ...        ...                        ...
# 15181                 Cindy Bertram         en           HGTV, discovery+
# 15182  Jesper Fink, Thomas Porsager         da                       TV 2
# 15183                  Hank and Jed         en                    YouTube
# 15184               Olivier Richard         fr             Arte , Taiwan+
# 15185               François Chevré         fr  LCP - Assemblée nationale
#
#       origin_country spoken_languages  \
# 0                 US          English
# 1                 ES          Español
# 2                 US          English
# 3                 US          English
# 4                 US          English
# ...              ...              ...
# 15181             US          English
# 15182             DK            Dansk
# 15183             US          English
# 15184             FR         Français
# 15185             FR         Français
#
#                                     production_companies  \
# 0      Revolution Sun Studios, Television 360, Genera...
# 1                                        Vancouver Media
# 2      21 Laps Entertainment, Monkey Massacre Product...
# 3      AMC Studios, Circle of Confusion, Valhalla Mot...
# 4      Warner Bros. Television, DC Entertainment, Jer...
# ...                                                  ...
# 15181                          Glass Entertainment Group
# 15182                                         Cosmo Film
# 15183                                       Hank and Jed
# 15184    ARTE, Zorba Production, Volos Films, TaiwanPlus
# 15185                          LCP - Assemblée nationale
#
#                            production_countries episode_run_time
# 0      United Kingdom, United States of America                0
# 1                                         Spain               70
# 2                      United States of America                0
# 3                      United States of America               42
# 4                      United States of America               45
# ...                                         ...              ...
# 15181                  United States of America                0
# 15182                                   Denmark                0
# 15183                  United States of America              333
# 15184                            France, Taiwan                0
# 15185                                    France               52
#
# [15186 rows x 25 columns]

# %%
alt.Chart(tvseries_df).mark_bar().encode(
    x='year(first_air_date):O',
    y='count()',
    tooltip='count()',
).interactive()
# Out:
# alt.Chart(...)

# %%
print(len(tvseries_df))
include = tvseries_df[tvseries_df['first_air_date'].dt.year >= 1990]
print(len(include))
# Out:
# 16751
# 15191

# %%
# Explore trends in TV show popularity based on vote count and average.
alt.Chart(tvseries_df.head(5000)).mark_circle(size=60).encode(
    x='vote_average',
    y='vote_count',
    # color='Origin',
    tooltip=['name', 'vote_count', 'vote_average']
).interactive()
# .properties(
#     width=1000,
#     height=600
# ).interactive()
# Out:
# alt.Chart(...)

# %%
# Identify the most prolific TV show creators or production companies based on the number of shows they have created.
# print(tvseries_df["created_by"])
# print(tvseries_df.dtypes)
alt.Chart(tvseries_df.head(100)).mark_bar().encode(
    x='created_by',
    y='count()'
).interactive()
# .transform_filter(
    # datum.year == 2000
# )


# alt.Chart().mark_bar().encode(
#     y='created_by',
#     x='number_of_seasons'
# )
# Out:
# alt.Chart(...)

# %%
tvseries_df['genre'] = tvseries_df['genres'].str.split(",")
tvseries_df2 = tvseries_df.explode('genre')
# print(tvseries_df2.head(5))

# %%
tvseries_df2.head(5)
# Out:
#    Unnamed: 0     id             name  number_of_seasons  number_of_episodes  \
# 0           0   1399  Game of Thrones                  8                  73
# 0           0   1399  Game of Thrones                  8                  73
# 0           0   1399  Game of Thrones                  8                  73
# 1           1  71446      Money Heist                  3                  41
# 1           1  71446      Money Heist                  3                  41
#
#   original_language  vote_count  vote_average  adult first_air_date  ...  \
# 0                en       21857         8.442  False     2011-04-17  ...
# 0                en       21857         8.442  False     2011-04-17  ...
# 0                en       21857         8.442  False     2011-04-17  ...
# 1                es       17836         8.257  False     2017-05-02  ...
# 1                es       17836         8.257  False     2017-05-02  ...
#
#                                         genres                 created_by  \
# 0  Sci-Fi & Fantasy, Drama, Action & Adventure  David Benioff, D.B. Weiss
# 0  Sci-Fi & Fantasy, Drama, Action & Adventure  David Benioff, D.B. Weiss
# 0  Sci-Fi & Fantasy, Drama, Action & Adventure  David Benioff, D.B. Weiss
# 1                                 Crime, Drama                  Álex Pina
# 1                                 Crime, Drama                  Álex Pina
#
#   languages           networks origin_country spoken_languages  \
# 0        en                HBO             US          English
# 0        en                HBO             US          English
# 0        en                HBO             US          English
# 1        es  Netflix, Antena 3             ES          Español
# 1        es  Netflix, Antena 3             ES          Español
#
#                                 production_companies  \
# 0  Revolution Sun Studios, Television 360, Genera...
# 0  Revolution Sun Studios, Television 360, Genera...
# 0  Revolution Sun Studios, Television 360, Genera...
# 1                                    Vancouver Media
# 1                                    Vancouver Media
#
#                        production_countries episode_run_time  \
# 0  United Kingdom, United States of America                0
# 0  United Kingdom, United States of America                0
# 0  United Kingdom, United States of America                0
# 1                                     Spain               70
# 1                                     Spain               70
#
#                  genre
# 0     Sci-Fi & Fantasy
# 0                Drama
# 0   Action & Adventure
# 1                Crime
# 1                Drama
#
# [5 rows x 26 columns]

# %%
alt.Chart(tvseries_df2.head(5)).mark_bar().encode(
    x='genre',
    y='count()'
).interactive()
# Out:
# alt.Chart(...)

# %%
from vega_datasets import data
pop = data.population_engineers_hurricanes()
pop.head()
# pop[['state', 'id']].to_dict()
# dict(zip(pop.state, pop.id))
# Out:
#         state  id  population  engineers  hurricanes
# 0     Alabama   1     4863300   0.003422          22
# 1      Alaska   2      741894   0.001591           0
# 2     Arizona   4     6931071   0.004774           0
# 3    Arkansas   5     2988248   0.002440           0
# 4  California   6    39250017   0.007126           0

# %%
states = alt.topo_feature(data.us_10m.url, 'states')
print(states.to_json())


alt.Chart(states).mark_geoshape().encode(
    color='population:Q'
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(pop, 'id', list(pop.columns))
).properties(
    width=500,
    height=300
).project(
    type='albersUsa'
)
# Out:
# {
#   "format": {
#     "feature": "states",
#     "type": "topojson"
#   },
#   "url": "https://cdn.jsdelivr.net/npm/vega-datasets@v1.29.0/data/us-10m.json"
# }
# alt.Chart(...)

# %%
map_states_id = {'Alabama': 1,
 'Alaska': 2,
 'Arizona': 4,
 'Arkansas': 5,
 'California': 6,
 'Colorado': 8,
 'Connecticut': 9,
 'Delaware': 10,
 'District of Columbia': 11,
 'Florida': 12,
 'Georgia': 13,
 'Hawaii': 15,
 'Idaho': 16,
 'Illinois': 17,
 'Indiana': 18,
 'Iowa': 19,
 'Kansas': 20,
 'Kentucky': 21,
 'Louisiana': 22,
 'Maine': 23,
 'Maryland': 24,
 'Massachusetts': 25,
 'Michigan': 26,
 'Minnesota': 27,
 'Mississippi': 28,
 'Missouri': 29,
 'Montana': 30,
 'Nebraska': 31,
 'Nevada': 32,
 'New Hampshire': 33,
 'New Jersey': 34,
 'New Mexico': 35,
 'New York': 36,
 'North Carolina': 37,
 'North Dakota': 38,
 'Ohio': 39,
 'Oklahoma': 40,
 'Oregon': 41,
 'Pennsylvania': 42,
 'Rhodes Island': 44,
 'South Carolina': 45,
 'South Dakota': 46,
 'Tennessee': 47,
 'Texas': 48,
 'Utah': 49,
 'Vermont': 50,
 'Virginia': 51,
 'Washington': 53,
 'West Virginia': 54,
 'Wisconsin': 55,
 'Wyoming': 56,
 'Puerto Rico': 72}

homicides_df["State ID"] = homicides_df["State"].map(map_states_id)
homicides_df = homicides_df.astype({"State ID": int})

# %%
homicides_df.head()
# print(homicides_df["State ID"].unique())
# Out:
#    Record ID Agency Code Agency Name       Agency Type       City   State  \
# 0          1     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 1          2     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 2          3     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 3          4     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 4          5     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
#
#    Year    Month  Incident              Crime Type  ... Perpetrator Sex  \
# 0  1980  January         1  Murder or Manslaughter  ...            Male
# 1  1980    March         1  Murder or Manslaughter  ...            Male
# 2  1980    March         2  Murder or Manslaughter  ...         Unknown
# 3  1980    April         1  Murder or Manslaughter  ...            Male
# 4  1980    April         2  Murder or Manslaughter  ...         Unknown
#
#   Perpetrator Age               Perpetrator Race Perpetrator Ethnicity  \
# 0              15  Native American/Alaska Native               Unknown
# 1              42                          White               Unknown
# 2               0                        Unknown               Unknown
# 3              42                          White               Unknown
# 4               0                        Unknown               Unknown
#
#    Relationship         Weapon  Victim Count Perpetrator Count Record Source  \
# 0  Acquaintance   Blunt Object             0                 0           FBI
# 1  Acquaintance  Strangulation             0                 0           FBI
# 2       Unknown        Unknown             0                 0           FBI
# 3  Acquaintance  Strangulation             0                 0           FBI
# 4       Unknown        Unknown             0                 1           FBI
#
#   State ID
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#
# [5 rows x 25 columns]

# %%
homocides_sum_by_state_df = homicides_df.groupby(['State ID', 'State'], as_index=False).sum('Incident')
homocides_sum_by_state_df.head()

data['subjects'].value_counts()['php']
# print(homocides_sum_by_state_df.columns)
# Out:
#    State ID       State    Record ID       Year  Incident  Victim Age  \
# 0         1     Alabama   3107984831   22680685     38149      494547
# 1         2      Alaska    500600479    3227204      2704       55379
# 2         4     Arizona   4657760650   25722653     61337      465003
# 3         5    Arkansas   2186342405   13866208     12898      276512
# 4         6  California  30328411741  199099051   1011666     3233503
#
#    Perpetrator Age  Victim Count  Perpetrator Count
# 0           267515           512                738
# 1            40097           380                213
# 2           258285          1698               1908
# 3           182422          1068               1484
# 4          1828125         11450              19198

# %%
# print(homicides_df.columns)
# print(homocides_sum_by_state_df["State"].unique())

alt.Chart(states).mark_geoshape().encode(
    tooltip=['State:N', 'Incident:Q'],
    color='Incident:Q'
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(homocides_sum_by_state_df, 'State ID', list(homocides_sum_by_state_df.columns))
).properties(
    width=500,
    height=300
).project(
    type='albersUsa'
).interactive()
# Out:
# alt.Chart(...)
